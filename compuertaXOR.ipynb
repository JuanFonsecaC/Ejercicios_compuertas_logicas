# %%
#importar librerias
import numpy as np
from numpy import sin, cos, tan, arctan, pi, matmul,arange
import matplotlib.pyplot as plt
import random as rd
from random import randint, random, uniform

# %%
#datos
alfa=1 #factor aprendizaje
p=np.array([   [0,0,1,1],[0,1,0,1]   ])
t=np.array([0,1,1,0])
#W=np.array([0.5,1.5])
W=np.random.rand(2)
#b=1.5
b=np.random.rand(1)

# %%
#funcion
def escalon1(x):
    if x<0:
        y=0
    else:
        y=1
    return y 
#r1=escalon(0)
#print(r1)

# %%
#ciclos de Aprendizaje
errorT = 1
jj = 0
iteraciones = 0
while errorT != 0 and iteraciones < 500: # Ciclos de aprendizaje (iterar)    
    errorT = 0    
    for k in range(4):
        pp = p[:, k]
        aa = matmul(W, pp) + b
        a = escalon1(aa)
        error = t[k] - a
        W = W + alfa * error * pp.transpose()
        b = b + alfa * error * 1
        errorT = errorT + abs(error)        
        # print(pp)
        # print(aa, "  ", a, "  ", error)
        # print(W, "  ", b)       
     
    #end k
    print("jj=", jj, "  ", errorT)
    print(W, "  ", b)  
    jj += 1 
    iteraciones += 1
    #if errorT == 0:
        #break
#end while
# Out:
# jj= 0    2
# [-0.35640536 -0.2167036 ]    [-1.41780676]
# jj= 1    3
# [-0.35640536 -0.2167036 ]    [-0.41780676]
# jj= 2    2
# [-1.35640536 -0.2167036 ]    [-0.41780676]
# jj= 3    3
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 4    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 5    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 6    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 7    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 8    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 9    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 10    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 11    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 12    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 13    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 14    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 15    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 16    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 17    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 18    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 19    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 20    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 21    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 22    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 23    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 24    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 25    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 26    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 27    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 28    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 29    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 30    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 31    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 32    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 33    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 34    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 35    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 36    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 37    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 38    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 39    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 40    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 41    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 42    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 43    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 44    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 45    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 46    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 47    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 48    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 49    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 50    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 51    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 52    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 53    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 54    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 55    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 56    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 57    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 58    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 59    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 60    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 61    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 62    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 63    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 64    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 65    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 66    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 67    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 68    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 69    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 70    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 71    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 72    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 73    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 74    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 75    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 76    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 77    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 78    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 79    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 80    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 81    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 82    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 83    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 84    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 85    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 86    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 87    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 88    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 89    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 90    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 91    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 92    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 93    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 94    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 95    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 96    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 97    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 98    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 99    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 100    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 101    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 102    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 103    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 104    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 105    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 106    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 107    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 108    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 109    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 110    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 111    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 112    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 113    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 114    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 115    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 116    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 117    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 118    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 119    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 120    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 121    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 122    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 123    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 124    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 125    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 126    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 127    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 128    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 129    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 130    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 131    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 132    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 133    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 134    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 135    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 136    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 137    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 138    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 139    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 140    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 141    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 142    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 143    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 144    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 145    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 146    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 147    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 148    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 149    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 150    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 151    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 152    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 153    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 154    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 155    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 156    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 157    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 158    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 159    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 160    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 161    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 162    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 163    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 164    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 165    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 166    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 167    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 168    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 169    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 170    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 171    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 172    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 173    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 174    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 175    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 176    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 177    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 178    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 179    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 180    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 181    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 182    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 183    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 184    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 185    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 186    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 187    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 188    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 189    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 190    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 191    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 192    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 193    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 194    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 195    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 196    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 197    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 198    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 199    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 200    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 201    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 202    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 203    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 204    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 205    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 206    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 207    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 208    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 209    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 210    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 211    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 212    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 213    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 214    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 215    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 216    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 217    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 218    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 219    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 220    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 221    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 222    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 223    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 224    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 225    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 226    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 227    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 228    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 229    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 230    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 231    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 232    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 233    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 234    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 235    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 236    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 237    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 238    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 239    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 240    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 241    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 242    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 243    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 244    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 245    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 246    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 247    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 248    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 249    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 250    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 251    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 252    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 253    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 254    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 255    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 256    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 257    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 258    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 259    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 260    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 261    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 262    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 263    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 264    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 265    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 266    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 267    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 268    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 269    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 270    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 271    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 272    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 273    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 274    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 275    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 276    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 277    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 278    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 279    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 280    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 281    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 282    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 283    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 284    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 285    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 286    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 287    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 288    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 289    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 290    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 291    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 292    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 293    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 294    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 295    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 296    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 297    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 298    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 299    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 300    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 301    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 302    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 303    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 304    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 305    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 306    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 307    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 308    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 309    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 310    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 311    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 312    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 313    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 314    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 315    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 316    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 317    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 318    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 319    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 320    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 321    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 322    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 323    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 324    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 325    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 326    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 327    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 328    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 329    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 330    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 331    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 332    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 333    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 334    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 335    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 336    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 337    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 338    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 339    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 340    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 341    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 342    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 343    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 344    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 345    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 346    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 347    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 348    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 349    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 350    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 351    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 352    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 353    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 354    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 355    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 356    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 357    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 358    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 359    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 360    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 361    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 362    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 363    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 364    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 365    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 366    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 367    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 368    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 369    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 370    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 371    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 372    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 373    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 374    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 375    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 376    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 377    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 378    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 379    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 380    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 381    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 382    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 383    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 384    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 385    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 386    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 387    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 388    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 389    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 390    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 391    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 392    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 393    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 394    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 395    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 396    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 397    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 398    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 399    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 400    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 401    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 402    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 403    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 404    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 405    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 406    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 407    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 408    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 409    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 410    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 411    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 412    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 413    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 414    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 415    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 416    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 417    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 418    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 419    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 420    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 421    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 422    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 423    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 424    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 425    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 426    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 427    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 428    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 429    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 430    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 431    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 432    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 433    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 434    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 435    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 436    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 437    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 438    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 439    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 440    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 441    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 442    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 443    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 444    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 445    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 446    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 447    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 448    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 449    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 450    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 451    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 452    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 453    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 454    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 455    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 456    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 457    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 458    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 459    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 460    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 461    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 462    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 463    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 464    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 465    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 466    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 467    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 468    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 469    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 470    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 471    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 472    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 473    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 474    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 475    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 476    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 477    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 478    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 479    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 480    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 481    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 482    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 483    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 484    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 485    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 486    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 487    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 488    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 489    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 490    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 491    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 492    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 493    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 494    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 495    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 496    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 497    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 498    4
# [-1.35640536 -0.2167036 ]    [0.58219324]
# jj= 499    4
# [-1.35640536 -0.2167036 ]    [0.58219324]

# %%
#graficas
# %matplotlib inline
print("Datos:")
print("W1:",W[0])
print("W2:",W[1]) 
print("b:",b)

plt.title('RNA compuerta XOR')
plt.xlabel('X1')
plt.ylabel('X2')
plt.plot([0,1],[0,1], "ko",[0,1],[1,0], "ro")
plt.axis([-1,2,-1,2])
plt.grid()
W1 = W[0]
W2 = W[1]

x = arange(-3, 3)
y = -(W[0] * x + b[0]) / W[1]
plt.plot(x, y)
plt.scatter(p[0], p[1], c=t)
plt.show()
# Out:
# Datos:
# W1: -1.3564053585697295
# W2: -0.2167036043623889
# b: [0.58219324]
