# %%
#importar librerias
import numpy as np
from numpy import sin, cos, tan, arctan, pi, matmul,arange
import matplotlib.pyplot as plt
import random as rd
from random import randint, random, uniform

# %%
#funcion
def escalon1(x):
    if x<0:
        y=0
    else:
        y=1
    return y 
#r1=escalon(0)
#print(r1)

# %%
#datos
alfa=1 #factor aprendizaje
p=np.array([   [0,0,1,1],[0,1,0,1]   ])
t=np.array([0,0,0,1])
#W=np.array([0.5,1.5])
W=np.random.rand(2)
#b=1.5
b=np.random.rand(1)

# %%
#ciclos de Aprendizaje
errorT = 1
jj = 0
while errorT != 0:# Ciclos de aprendizaje (iterar)    
    errorT = 0    
    for k in range(4):
        pp = p[:, k]
        aa = matmul(W, pp) + b
        a = escalon1(aa)
        error = t[k] - a
        W = W + alfa * error * pp.transpose()
        b = b + alfa * error * 1
        errorT = errorT + abs(error)        
        # print(pp)
        # print(aa, "  ", a, "  ", error)
        # print(W, "  ", b)       
     
    #end k
    print("jj=", jj, "  ", errorT)
    print("W=", W ,"  ", b)  
    jj += 1 
    #if errorT == 0:
        #break
#end while
# Out:
# jj= 0    3
# W= [1.03951042 0.69187471]    [-0.03715086]
# jj= 1    3
# W= [1.03951042 0.69187471]    [-1.03715086]
# jj= 2    2
# W= [1.03951042 1.69187471]    [-1.03715086]
# jj= 3    2
# W= [2.03951042 1.69187471]    [-1.03715086]
# jj= 4    3
# W= [2.03951042 1.69187471]    [-2.03715086]
# jj= 5    2
# W= [2.03951042 2.69187471]    [-2.03715086]
# jj= 6    1
# W= [2.03951042 1.69187471]    [-3.03715086]
# jj= 7    0
# W= [2.03951042 1.69187471]    [-3.03715086]

# %%
# %matplotlib inline
print("Datos:")
print("W1:",W[0])
print("W2:",W[1]) 
print("b:",b)

plt.title('RNA compuerta AND')
plt.xlabel('X1')
plt.ylabel('X2')
plt.plot([1,1],"ro" ,[0,1,0],[0,0,1],"ko")
plt.axis([-1,2,-1,2])
plt.grid()

x = arange(-3, 3)
y = -(W[0] * x + b[0]) / W[1]
plt.plot(x, y)
plt.scatter(p[0], p[1], c=t)
plt.show()
# Out:
# Datos:
# W1: 2.039510422763523
# W2: 1.6918747136322665
# b: [-3.03715086]
